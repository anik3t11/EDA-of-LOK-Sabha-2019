# %% [markdown]
# # LOK SABHA
#
# ![](https://i2.wp.com/opportunitycell.com/wp-content/uploads/2021/06/lok-sabha-india-2-638.jpg?fit=638%2C479&ssl=1)
#
#    #### General elections were held in India in seven phases from 11 April to 19 May 2019 to elect the members of the 17th Lok Sabha. Votes were counted and the result declared on 23 May. Around 912 million people were eligible to vote, and voter turnout was over 67 percent – the highest ever, as well as the highest ever participation by women voters.
# #### All 543 elected MPs are elected from single-member constituencies using first-past-the-post voting. The President of India appoints an additional two members from the Anglo-Indian community if he believes that community is under-represented.
# #### Eligible voters must be Indian citizens, 18 or older than 18, an ordinary resident of the polling area of the constituency and registered to vote (name included in the electoral rolls), possess a valid voter identification card issued by the Election Commission of India or an equivalent. Some people convicted of electoral or other offences are barred from voting.
# #### The elections are held on schedule and as per the Constitution of India that mandates parliamentary elections once every five years.
# #### In this analysis report we will analyze the LOK SABHA 2019 result. I have downloaded the election data set from kaggle with over 2,264 no. of rows and 19 column consisting of different parameter.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline

# %% [markdown]
# Imported Different moeules that will help us in analysis

# %%
sns.set_style('whitegrid')
matplotlib.rcParams['font.size'] =14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %% [markdown]
# Set parameters for visualization to get the output in desire shape

# %%
elec_df = pd.read_csv('LS_2.0.csv')
elec_df
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 2         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2261      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 0     Lotus   MALE              52  52.0       ST      12th Pass
# 1      Hand   MALE               3  52.0       ST      12th Pass
# 2       Car   MALE               0  54.0       ST  Post Graduate
# 3       NaN    NaN             NaN   NaN      NaN            NaN
# 4     Lotus   MALE               5  58.0       SC      Doctorate
# ...     ...    ...             ...   ...      ...            ...
# 2258   SHIP   MALE               0  43.0  GENERAL  Post Graduate
# 2259    Car   MALE              18  63.0  GENERAL       Graduate
# 2260  Lotus   MALE               3  47.0  GENERAL      12th Pass
# 2261   Hand   MALE               0  49.0  GENERAL  Post Graduate
# 2262    NaN    NaN             NaN   NaN      NaN            NaN
#
#               ASSETS  LIABILITIES  GENERAL\nVOTES  POSTAL\nVOTES  \
# 0          30,99,414     2,31,450          376892            482
# 1        3,64,91,000  1,53,00,000          314057            181
# 2        1,84,77,888     8,47,000          318665            149
# 3                NaN          NaN           13030              6
# 4        7,42,74,036    86,06,522          644459           2416
# ...              ...          ...             ...            ...
# 2258       48,90,000    10,20,000           14661             25
# 2259  1,28,78,51,556  1,15,35,000          434066            178
# 2260     5,85,77,327    52,50,000          138731            216
# 2261    90,36,63,001            0          427900            115
# 2262             NaN          NaN           11138              2
#
#       TOTAL\nVOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0           377374                              25.330684
# 1           314238                              21.092771
# 2           318814                              21.399929
# 3            13036                               0.875023
# 4           646875                              33.383823
# ...            ...                                    ...
# 2258         14686                               0.766419
# 2259        434244                              28.975369
# 2260        138947                               9.271379
# 2261        428015                              28.559732
# 2262         11140                               0.743328
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.534285         1489790
# 2                                     29.964370         1489790
# 3                                      1.225214         1489790
# 4                                     56.464615         1937690
# ...                                         ...             ...
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  13.302678         1498666
# 2261                                  40.977823         1498666
# 2262                                   1.066535         1498666
#
# [2263 rows x 19 columns]

# %% [markdown]
# Imported CSV file that we are going to analyze

# %%
elec_df.shape
# Out:
# (2263, 19)

# %% [markdown]
# fom this we get to k/w the size of table i.e. it contain 2263rows and 19 columns.

# %%
elec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   CRIMINAL
# CASES                            2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
#  10  EDUCATION                                 2018 non-null   object
#  11  ASSETS                                    2014 non-null   object
#  12  LIABILITIES                               2017 non-null   object
#  13  GENERAL
# VOTES                             2263 non-null   int64
#  14  POSTAL
# VOTES                              2263 non-null   int64
#  15  TOTAL
# VOTES                               2263 non-null   int64
#  16  OVER TOTAL ELECTORS
# IN CONSTITUENCY      2263 non-null   float64
#  17  OVER TOTAL VOTES POLLED
# IN CONSTITUENCY  2263 non-null   float64
#  18  TOTAL ELECTORS                            2263 non-null   int64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 336.0+ KB

# %%
elec_df.NAME.value_counts().drop('NOTA').head(10)
# Out:
# SANJAY KUMAR              2
# ATUL KUMAR SINGH          2
# Rahul Gandhi              2
# Ajay Kumar                2
# SURENDRA RAM              2
# SYED NAJEEB SHAH NAQVI    1
# DR. SHRILAL KISKU         1
# ASHOK KUMAR KANAUJIYA     1
# RAJENDRA SAHU             1
# A.K. MOORTHY              1
# Name: NAME, dtype: int64

# %%
elec_winner =  elec_df[elec_df.WINNER >0]
elec_winner
# Out:
#               STATE     CONSTITUENCY                               NAME  \
# 0         Telangana         ADILABAD                     SOYAM BAPU RAO
# 4     Uttar Pradesh             AGRA              Satyapal Singh Baghel
# 8       Maharashtra       AHMADNAGAR  Dr. SUJAY RADHAKRISHNA VIKHEPATIL
# 11          Gujarat   AHMEDABAD EAST         Patel Hasmukhbhai Somabhai
# 12          Gujarat   AHMEDABAD WEST               DR. KIRIT P. SOLANKI
# ...             ...              ...                                ...
# 2245    Maharashtra           WARDHA         Ramdas Chandrabhanji Tadas
# 2248         Kerala          WAYANAD                       Rahul Gandhi
# 2251   NCT OF Delhi       WEST DELHI          PARVESH SAHIB SINGH VERMA
# 2253    Maharashtra  YAVATMAL-WASHIM          Bhavana Pundlikrao Gawali
# 2259      Telangana        ZAHIRABAD                          B.B.PATIL
#
#       WINNER PARTY         SYMBOL  GENDER CRIMINAL\nCASES   AGE CATEGORY  \
# 0          1   BJP          Lotus    MALE              52  52.0       ST
# 4          1   BJP          Lotus    MALE               5  58.0       SC
# 8          1   BJP          Lotus    MALE               0  37.0  GENERAL
# 11         1   BJP          Lotus    MALE               0  58.0  GENERAL
# 12         1   BJP          Lotus    MALE               0  69.0       SC
# ...      ...   ...            ...     ...             ...   ...      ...
# 2245       1   BJP          Lotus    MALE               0  65.0  GENERAL
# 2248       1   INC           Hand    MALE               5  48.0  GENERAL
# 2251       1   BJP          Lotus    MALE               0  41.0  GENERAL
# 2253       1   SHS  Bow and Arrow  FEMALE               3  46.0  GENERAL
# 2259       1   TRS            Car    MALE              18  63.0  GENERAL
#
#           EDUCATION          ASSETS  LIABILITIES  GENERAL\nVOTES  \
# 0         12th Pass       30,99,414     2,31,450          376892
# 4         Doctorate     7,42,74,036    86,06,522          644459
# 8         Doctorate    16,86,64,576    26,23,964          696961
# 11           Others     7,46,99,690    62,52,577          745810
# 12    Post Graduate     8,94,74,039            0          638241
# ...             ...             ...          ...             ...
# 2245      10th Pass     6,58,07,822    89,61,387          575488
# 2248  Post Graduate    15,88,77,063    72,01,904          705034
# 2251  Post Graduate    15,51,95,014  4,00,97,329          862058
# 2253       Graduate     9,68,73,189    73,96,250          540104
# 2259       Graduate  1,28,78,51,556  1,15,35,000          434066
#
#       POSTAL\nVOTES  TOTAL\nVOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0               482        377374                              25.330684
# 4              2416        646875                              33.383823
# 8              7699        704660                              37.856533
# 11             4024        749834                              41.384970
# 12             3381        641622                              39.044323
# ...             ...           ...                                    ...
# 2245           2876        578364                              33.176713
# 2248           1333        706367                              51.951012
# 2251           3590        865648                              36.499913
# 2253           1994        542098                              28.290483
# 2259            178        434244                              28.975369
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 4                                     56.464615         1937690
# 8                                     58.425159         1861396
# 11                                    67.005462         1811851
# 12                                    64.211450         1643317
# ...                                         ...             ...
# 2245                                  53.918820         1743283
# 2248                                  64.640694         1359679
# 2251                                  60.010593         2371644
# 2253                                  46.142912         1916185
# 2259                                  41.574183         1498666
#
# [539 rows x 19 columns]

# %% [markdown]
# Extracted winner from the csv file who won the election

# %%
elec_loss = elec_df[elec_df.WINNER<1]
elec_loss
# Out:
#               STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 1         Telangana         ADILABAD           RATHOD RAMESH       0    INC
# 2         Telangana         ADILABAD            Godam Nagesh       0    TRS
# 3         Telangana         ADILABAD                    NOTA       0   NOTA
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni       0    BSP
# 6     Uttar Pradesh             AGRA            Preeta Harit       0    INC
# ...             ...              ...                     ...     ...    ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2260      Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
# 2261      Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2262      Telangana        ZAHIRABAD                    NOTA       0   NOTA
#
#         SYMBOL  GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 1         Hand    MALE               3  52.0       ST      12th Pass
# 2          Car    MALE               0  54.0       ST  Post Graduate
# 3          NaN     NaN             NaN   NaN      NaN            NaN
# 5     Elephant    MALE               0  47.0       SC  Post Graduate
# 6         Hand  FEMALE               0  54.0       SC  Post Graduate
# ...        ...     ...             ...   ...      ...            ...
# 2257   Whistle  FEMALE               0  28.0  GENERAL      10th Pass
# 2258      SHIP    MALE               0  43.0  GENERAL  Post Graduate
# 2260     Lotus    MALE               3  47.0  GENERAL      12th Pass
# 2261      Hand    MALE               0  49.0  GENERAL  Post Graduate
# 2262       NaN     NaN             NaN   NaN      NaN            NaN
#
#             ASSETS  LIABILITIES  GENERAL\nVOTES  POSTAL\nVOTES  TOTAL\nVOTES  \
# 1      3,64,91,000  1,53,00,000          314057            181        314238
# 2      1,84,77,888     8,47,000          318665            149        318814
# 3              NaN          NaN           13030              6         13036
# 5     13,37,84,385  2,22,51,891          434199           1130        435329
# 6      5,50,75,753            0           44877            272         45149
# ...            ...          ...             ...            ...           ...
# 2257     11,68,500        9,000           20563             57         20620
# 2258     48,90,000    10,20,000           14661             25         14686
# 2260   5,85,77,327    52,50,000          138731            216        138947
# 2261  90,36,63,001            0          427900            115        428015
# 2262           NaN          NaN           11138              2         11140
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 1                                 21.092771
# 2                                 21.399929
# 3                                  0.875023
# 5                                 22.466390
# 6                                  2.330042
# ...                                     ...
# 2257                               1.076097
# 2258                               0.766419
# 2260                               9.271379
# 2261                              28.559732
# 2262                               0.743328
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 1                                     29.534285         1489790
# 2                                     29.964370         1489790
# 3                                      1.225214         1489790
# 5                                     37.999125         1937690
# 6                                      3.940979         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2260                                  13.302678         1498666
# 2261                                  40.977823         1498666
# 2262                                   1.066535         1498666
#
# [1724 rows x 19 columns]

# %% [markdown]
# Contestant who faced defeat in the election

# %% [markdown]
# ## Tabluating table for parties contesting the election
# ### and
# ## Winning The Election

# %%
#tabluating the winning party 
win_party =elec_winner.PARTY.value_counts()
win_party
# Out:
# BJP       300
# INC        52
# DMK        23
# AITC       22
# YSRCP      22
# SHS        18
# JD(U)      16
# BSP        11
# BJD        11
# TRS         9
# LJP         6
# SP          5
# NCP         5
# CPI(M)      5
# IND         4
# TDP         3
# JKN         3
# IUML        3
# AIMIM       2
# SAD         2
# ADAL        2
# JD(S)       1
# NPEP        1
# KEC(M)      1
# RLTP        1
# NDPP        1
# AIADMK      1
# AJSUP       1
# RSP         1
# NPF         1
# SKM         1
# VCK         1
# MNF         1
# AAP         1
# AIUDF       1
# JMM         1
# Name: PARTY, dtype: int64

# %% [raw]
# Parties won election on different seats.

# %%
win_last= win_party[6:]
win_last
# Out:
# JD(U)     16
# BSP       11
# BJD       11
# TRS        9
# LJP        6
# SP         5
# NCP        5
# CPI(M)     5
# IND        4
# TDP        3
# JKN        3
# IUML       3
# AIMIM      2
# SAD        2
# ADAL       2
# JD(S)      1
# NPEP       1
# KEC(M)     1
# RLTP       1
# NDPP       1
# AIADMK     1
# AJSUP      1
# RSP        1
# NPF        1
# SKM        1
# VCK        1
# MNF        1
# AAP        1
# AIUDF      1
# JMM        1
# Name: PARTY, dtype: int64

# %%
win_5 = win_party.head(5)
win_5['other']=win_last.sum()
win_5
# Out:
# BJP      300
# INC       52
# DMK       23
# AITC      22
# YSRCP     22
# other    102
# Name: PARTY, dtype: int64

# %% [markdown]
# top 5 parties won the election

# %%
final_list =win_5.copy()
final_list
# Out:
# BJP      300
# INC       52
# DMK       23
# AITC      22
# YSRCP     22
# other    102
# Name: PARTY, dtype: int64

# %%
total_party = elec_df.PARTY.value_counts()
total_last = total_party[6:]
total_5 = total_party.head(5)
total_5['others'] = total_last.sum()
total_5
# Out:
# BJP       420
# INC       413
# NOTA      245
# IND       201
# BSP       163
# others    721
# Name: PARTY, dtype: int64

# %% [raw]
# Parties contested the election

# %% [markdown]
# # Tabluating the contestant and winner based on Gender ratio!!
#
# Contested the election and winners based on the ration

# %%
gender_df=elec_df.GENDER.value_counts()
gender_df
# Out:
# MALE      1760
# FEMALE     258
# Name: GENDER, dtype: int64

# %%
gender_winner=elec_winner.GENDER.value_counts()
gender_winner
# Out:
# MALE      463
# FEMALE     76
# Name: GENDER, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('WINNER GENDER RATIO')
plt.pie(gender_winner,labels=gender_winner.index,autopct='%1.1f%%',startangle =180);
plt.figure(figsize=(12,6))
plt.title('Gender percentage who contest the Election')
plt.pie(gender_df,labels=gender_df.index,autopct='%1.1f%%',startangle =180);

# %% [markdown]
# ## Tabualation based on Category
#
# Contested the election based on their gender

# %%
category_df=elec_df.CATEGORY.value_counts()
category_df
# Out:
# GENERAL    1392
# SC          383
# ST          243
# Name: CATEGORY, dtype: int64

# %%
category_winner=elec_winner.CATEGORY.value_counts()
category_winner
# Out:
# GENERAL    399
# SC          85
# ST          55
# Name: CATEGORY, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Category percentage contest the Election')
plt.pie(category_df,labels=category_df.index,autopct='%1.1f%%',startangle =180);

plt.figure(figsize=(12,6))
plt.title('Category percentage WON the Election')
plt.pie(category_winner,labels=category_winner.index,autopct='%1.1f%%',startangle =180);

# %% [markdown]
# # Tabulation of contestant got Max. and Min. Votes
#
# Contested the elction andd got maximum and minimum votes

# %%
#Contestant winning with maximum margin
margin_df = elec_winner[['NAME','PARTY','CONSTITUENCY','STATE','TOTAL\nVOTES']]
margin_df['Win By'] = round(elec_winner['TOTAL\nVOTES']*100/elec_winner['TOTAL ELECTORS'])
margin_df = margin_df.sort_values(by='Win By',ascending = False).head(10)

margin_df
# Out:
# <ipython-input-21-3e63212e351e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   margin_df['Win By'] = round(elec_winner['TOTAL\nVOTES']*100/elec_winner['TOTAL ELECTORS'])
#                      NAME  PARTY    CONSTITUENCY             STATE  \
# 2248         Rahul Gandhi    INC         WAYANAD            Kerala
# 1068        Kishan Kapoor    BJP          KANGRA  Himachal Pradesh
# 886     UDAY PRATAP SINGH    BJP     HOSHANGABAD    Madhya Pradesh
# 1367   RAM SWAROOP SHARMA    BJP           MANDI  Himachal Pradesh
# 2175     ANANTKUMAR HEGDE    BJP  UTTARA KANNADA         Karnataka
# 1025    Y.S.Avinash Reddy  YSRCP          KADAPA    Andhra Pradesh
# 1113          Jothimani S    INC           KARUR        Tamil Nadu
# 650         RAMESWAR TELI    BJP       DIBRUGARH             Assam
# 840   ANURAG SINGH THAKUR    BJP        HAMIRPUR  Himachal Pradesh
# 1566          C. R. Patil    BJP         NAVSARI           Gujarat
#
#       TOTAL\nVOTES  Win By
# 2248        706367    52.0
# 1068        725218    51.0
# 886         877927    51.0
# 1367        647189    51.0
# 2175        786042    50.0
# 1025        783499    50.0
# 1113        695697    50.0
# 650         659583    50.0
# 840         682692    50.0
# 1566        972739    49.0

# %%
#Contestant winning with maximum margin
lessmargin_df = elec_winner[['NAME','PARTY','CONSTITUENCY','STATE','TOTAL\nVOTES']]
lessmargin_df['Win By'] = round(elec_winner['TOTAL\nVOTES']*100/elec_winner['TOTAL ELECTORS'])
lessmargin_df = lessmargin_df.sort_values(by='Win By',ascending = True).head(10)

lessmargin_df
# Out:
# <ipython-input-22-5375a5671e08>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lessmargin_df['Win By'] = round(elec_winner['TOTAL\nVOTES']*100/elec_winner['TOTAL ELECTORS'])
#                        NAME  PARTY CONSTITUENCY            STATE  \
# 171            NARESH YADAV    BSP   AURANGABAD            Bihar
# 101         HASNAIN MASOODI    JKN     ANANTNAG  Jammu & Kashmir
# 2006        Farooq Abdullah    JKN     SRINAGAR  Jammu & Kashmir
# 281     MOHAMMAD AKBAR LONE    JKN    BARAMULLA  Jammu & Kashmir
# 1361  ANUMULA REVANTH REDDY    INC   MALKAJGIRI        Telangana
# 1892       G . KISHAN REDDY    BJP  SECUNDRABAD        Telangana
# 1124     VINOD KUMAR SONKAR    BJP    KAUSHAMBI    Uttar Pradesh
# 172      Imtiaz Jaleel Syed  AIMIM   AURANGABAD      Maharashtra
# 925      CHANDESHWAR PRASAD  JD(U)    JAHANABAD            Bihar
# 518    Dr. G. Ranjith Reddy    TRS     CHEVELLA        Telangana
#
#       TOTAL\nVOTES  Win By
# 171          33772     2.0
# 101          40180     3.0
# 2006        106750     8.0
# 281         133426    10.0
# 1361        603748    19.0
# 1892        384780    20.0
# 1124        383009    21.0
# 172         389042    21.0
# 925         335584    21.0
# 518         528148    22.0

# %%
#Contestant got least% votes all over india
least_df = elec_df[['NAME','PARTY','CONSTITUENCY','STATE','TOTAL\nVOTES']]
least_df['Win By'] = (elec_df['TOTAL\nVOTES']*100/elec_df['TOTAL ELECTORS'])
least_df = least_df.sort_values(by='Win By',ascending = True).head(10)

least_df
# Out:
# <ipython-input-23-ea2c61405f98>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   least_df['Win By'] = (elec_df['TOTAL\nVOTES']*100/elec_df['TOTAL ELECTORS'])
#                         NAME  PARTY  CONSTITUENCY            STATE  \
# 104           GH. MOHD. WANI    IND      ANANTNAG  Jammu & Kashmir
# 103           CH. ZAFFAR ALI    JPC      ANANTNAG  Jammu & Kashmir
# 2007  Sheikh Khalid Jehangir    BJP      SRINAGAR  Jammu & Kashmir
# 287   SYED NAJEEB SHAH NAQVI    IND     BARAMULLA  Jammu & Kashmir
# 1057   RAVINDRA (PINTU) KENE    BSP        KALYAN      Maharashtra
# 1894        N . SHANKAR GOUD    JnP   SECUNDRABAD        Telangana
# 1095            MAMTA PANDEY  RSPSR       KARAKAT            Bihar
# 1701                    NOTA   NOTA          PUNE      Maharashtra
# 1880            ASHOK BAITHA    IND  SASARAM (SC)            Bihar
# 1470  KUMAR NAVNEET HIMANSHU    BSP        MUNGER            Bihar
#
#       TOTAL\nVOTES    Win By
# 104           1369  0.097941
# 103           1646  0.117758
# 2007          4631  0.357697
# 287           4967  0.376934
# 1057          9627  0.489755
# 1894          9683  0.491953
# 1095          8851  0.499702
# 1701         11001  0.529958
# 1880         10029  0.560944
# 1470         10612  0.562069

# %%
x = least_df['NAME']
y = least_df['Win By']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='r')
plt.plot(x,y,color='g')
plt.xticks(rotation =60)
plt.title('Got Least Vote',color='r')
plt.xlabel('NAME OF POLITICIAN',color='r')
plt.ylabel('% of vote from Constituency',color='r');

# %%
x = margin_df['NAME']
y = margin_df['Win By']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='r')
plt.plot(x,y,color='g')
plt.xticks(rotation =60)
plt.title('WIN BY MOST MARGIN',color='r')
plt.xlabel('NAME OF POLITICIAN',color='r')
plt.ylabel('% of vote from Constituency',color='r');

# %% [markdown]
# # Tabulation of contestant with maximum number of Criminal Case
#
# Contestant having most number of criminal charges on them.

# %%
#Contestant with maximum number of criminal case
crime_df = elec_df[['PARTY','NAME','CONSTITUENCY','STATE','CRIMINAL\nCASES']].dropna()
crime_df= crime_df.replace('Not Available',0)
crime_df['CRIMINAL\nCASES']=crime_df['CRIMINAL\nCASES'].apply(pd.to_numeric)
crime_df = crime_df.sort_values(by='CRIMINAL\nCASES',ascending=False).head(10) 
crime_df
# Out:
#      PARTY                         NAME    CONSTITUENCY          STATE  \
# 1650   BJP                  K SURENDRAN  PATHANAMTHITTA         Kerala
# 903    INC          Adv. DEAN KURIAKOSE          IDUKKI         Kerala
# 0      BJP               SOYAM BAPU RAO        ADILABAD      Telangana
# 1361   INC        ANUMULA REVANTH REDDY      MALKAJGIRI      Telangana
# 2020   INC                George Tirkey      SUNDARGARH         Odisha
# 167    BJP               SOBHASURENDRAN        ATTINGAL         Kerala
# 1303  JAPL  Rajesh Ranjan @ Pappu Yadav       MADHEPURA          Bihar
# 457    BSP                 YOGESH VERMA     BULANDSHAHR  Uttar Pradesh
# 321    BJP                  ARJUN SINGH     BARRACKPORE    West Bengal
# 1233   BJP             Adv.PRAKASH BABU       KOZHIKODE         Kerala
#
#       CRIMINAL\nCASES
# 1650              240
# 903               204
# 0                  52
# 1361               42
# 2020               41
# 167                40
# 1303               31
# 457                28
# 321                24
# 1233               22

# %%
#present LS member with most no. of crime cases
crime_win = elec_winner[['PARTY','NAME','CONSTITUENCY','STATE','CRIMINAL\nCASES']].dropna()
crime_win= crime_win.replace('Not Available',0)
crime_win['CRIMINAL\nCASES']=crime_win['CRIMINAL\nCASES'].apply(pd.to_numeric)
crime_win = crime_win.sort_values(by='CRIMINAL\nCASES',ascending=False).head(10) 
crime_win
# Out:
#      PARTY                       NAME CONSTITUENCY          STATE  \
# 903    INC        Adv. DEAN KURIAKOSE       IDUKKI         Kerala
# 0      BJP             SOYAM BAPU RAO     ADILABAD      Telangana
# 1361   INC      ANUMULA REVANTH REDDY   MALKAJGIRI      Telangana
# 321    BJP                ARJUN SINGH  BARRACKPORE    West Bengal
# 2259   TRS                  B.B.PATIL    ZAHIRABAD      Telangana
# 882    BJP          LOCKET CHATTERJEE      HOOGHLY    West Bengal
# 409    INC  Komati Reddy Venkat Reddy      BHONGIR      Telangana
# 1415   BJP                Dilip Ghosh    MEDINIPUR    West Bengal
# 785    BSP           ATUL KUMAR SINGH        GHOSI  Uttar Pradesh
# 1074   BJP              SUBRAT PATHAK      KANNAUJ  Uttar Pradesh
#
#       CRIMINAL\nCASES
# 903               204
# 0                  52
# 1361               42
# 321                24
# 2259               18
# 882                14
# 409                14
# 1415               14
# 785                13
# 1074               11

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 1650 to 1233
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PARTY           10 non-null     object
#  1   NAME            10 non-null     object
#  2   CONSTITUENCY    10 non-null     object
#  3   STATE           10 non-null     object
#  4   CRIMINAL
# CASES  10 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 480.0+ bytes

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('No. of Criminal Cases')
plt.xlabel('Name of Contestant')
plt.ylabel('No. of Cases')
plt.plot(crime_df['NAME'],crime_df['CRIMINAL\nCASES'])
plt.scatter(crime_df['NAME'],crime_df['CRIMINAL\nCASES'],c='r');

# %% [markdown]
# # Table of Most aged person contested the election
#
# Contestant with maximum age

# %%
age_df = elec_df[['PARTY','NAME','CONSTITUENCY','STATE','AGE']].dropna().sort_values(by='AGE',ascending = False).head(5)
age_df
# Out:
#       PARTY                      NAME CONSTITUENCY            STATE   AGE
# 1855     SP  DR. SHAFIQUR REHMAN BARQ      SAMBHAL    Uttar Pradesh  86.0
# 2137  JD(S)           H. D. DEVEGOWDA       TUMKUR        Karnataka  86.0
# 2006    JKN           Farooq Abdullah     SRINAGAR  Jammu & Kashmir  83.0
# 939     SAD     Charanjit Singh Atwal    JALANDHAR           Punjab  82.0
# 797     IND               K. Rangaiah        GODDA        Jharkhand  82.0

# %%
win_age = elec_winner[['PARTY','NAME','CONSTITUENCY','STATE','AGE']].dropna().sort_values(by='AGE',ascending = False).head(5)
win_age
# Out:
#      PARTY                      NAME CONSTITUENCY            STATE   AGE
# 1855    SP  DR. SHAFIQUR REHMAN BARQ      SAMBHAL    Uttar Pradesh  86.0
# 2006   JKN           Farooq Abdullah     SRINAGAR  Jammu & Kashmir  83.0
# 1387  AITC     CHOUDHURY MOHAN JATUA   MATHURAPUR      West Bengal  80.0
# 1348    SP       MULAYAM SINGH YADAV     MAINPURI    Uttar Pradesh  79.0
# 712    INC          Mohammad Sadique     FARIDKOT           Punjab  78.0

# %%
x= age_df['NAME']
y= age_df['AGE']
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('OLDEST CONTESTANT TO RUN THE ELECTION')
plt.scatter(x,y)
plt.plot(x,y);

# %% [markdown]
# # Cities which pools maximum no. of votes
#
# Cities which pools maximum number of voters

# %%
most_elector= elec_df[['STATE','CONSTITUENCY','TOTAL ELECTORS']].sort_values(by='TOTAL ELECTORS',ascending = False).drop_duplicates().head(10)
most_elector
# Out:
#                STATE         CONSTITUENCY  TOTAL ELECTORS
# 1365       Telangana           MALKAJGIRI         3150313
# 238        Karnataka      BANGALORE NORTH         2849250
# 780    Uttar Pradesh            GHAZIABAD         2728978
# 242        Karnataka      BANGALORE RURAL         2497458
# 518        Telangana             CHEVELLA         2443112
# 1596    NCT OF Delhi     NORTH WEST DELHI         2378995
# 2250    NCT OF Delhi           WEST DELHI         2371644
# 2058     Maharashtra                THANE         2370903
# 906   Madhya Pradesh               INDORE         2350580
# 761    Uttar Pradesh  GAUTAM BUDDHA NAGAR         2302960

# %%
x= most_elector['CONSTITUENCY']
y= most_elector['TOTAL ELECTORS']
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('CITIES WITH HIGHEST ELECTORS')
plt.scatter(x,y)
plt.plot(x,y);

# %% [markdown]
# # Contestant Education
#
# Eduction of candidates

# %%
edu_df=elec_df.EDUCATION.value_counts().head(10)
edu_df
# Out:
# Post Graduate            502
# Graduate                 441
# Graduate Professional    336
# 12th Pass                256
# 10th Pass                196
# 8th Pass                  78
# Doctorate                 73
# Others                    50
# Literate                  30
# 5th Pass                  28
# Name: EDUCATION, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('EDUCATION OF CONTESTANT')
count =0
number= pd.DataFrame(edu_df)
number['num'] = edu_df
for i in number['num']:
    plt.text(count-0.1,i+1,str(i),c='black')
    count+=1
sns.barplot(edu_df.index,edu_df);
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ru_df =elec_df[['NAME','PARTY','STATE','CONSTITUENCY','ASSETS','LIABILITIES',]].dropna()

ru_df
# Out:
#                         NAME  PARTY          STATE     CONSTITUENCY  \
# 0             SOYAM BAPU RAO    BJP      Telangana         ADILABAD
# 1              RATHOD RAMESH    INC      Telangana         ADILABAD
# 2               Godam Nagesh    TRS      Telangana         ADILABAD
# 4      Satyapal Singh Baghel    BJP  Uttar Pradesh             AGRA
# 5           Manoj Kumar Soni    BSP  Uttar Pradesh             AGRA
# ...                      ...    ...            ...              ...
# 2257  Vaishali Sudhakar Yede  PHJSP    Maharashtra  YAVATMAL-WASHIM
# 2258      Anil Jayram Rathod    IND    Maharashtra  YAVATMAL-WASHIM
# 2259               B.B.PATIL    TRS      Telangana        ZAHIRABAD
# 2260      BANALA LAXMA REDDY    BJP      Telangana        ZAHIRABAD
# 2261         MADAN MOHAN RAO    INC      Telangana        ZAHIRABAD
#
#               ASSETS  LIABILITIES
# 0          30,99,414     2,31,450
# 1        3,64,91,000  1,53,00,000
# 2        1,84,77,888     8,47,000
# 4        7,42,74,036    86,06,522
# 5       13,37,84,385  2,22,51,891
# ...              ...          ...
# 2257       11,68,500        9,000
# 2258       48,90,000    10,20,000
# 2259  1,28,78,51,556  1,15,35,000
# 2260     5,85,77,327    52,50,000
# 2261    90,36,63,001            0
#
# [2013 rows x 6 columns]

# %%
rich_df=ru_df.sort_values(by='ASSETS',ascending=False)
rich_df
# Out:
#                         NAME PARTY              STATE    CONSTITUENCY  \
# 969          UPENDRA RAVIDAS   BSP              Bihar      JAMUI (SC)
# 2184             Rinkoo Devi   IND              Bihar        VAISHALI
# 686       PENTAPATI PULLARAO   JnP     Andhra Pradesh           ELURU
# 463   Ramchandra Singh Yadav   IND              Bihar           BUXAR
# 1693        N.SHARMILA BEGUM   NTK         Puducherry      PUDUCHERRY
# ...                      ...   ...                ...             ...
# 2120            RAMESHBABU R   NTK         Tamil Nadu  TIRUVANNAMALAI
# 1244          INTAJ ALI SHAH   INC        West Bengal    KRISHNANAGAR
# 287   SYED NAJEEB SHAH NAQVI   IND    Jammu & Kashmir       BARAMULLA
# 152               NABAM TUKI   INC  Arunachal Pradesh  ARUNACHAL WEST
# 568             K. THANGAVEL   IND         Tamil Nadu       CUDDALORE
#
#               ASSETS   LIABILITIES
# 969        Available     Available
# 2184       Available     Available
# 686        Available     Available
# 463        Available     Available
# 1693       Available     Available
# ...              ...           ...
# 2120     1,00,60,000      8,50,000
# 1244     1,00,54,478             0
# 287      1,00,50,737     67,86,855
# 152   1,00,29,50,534  20,49,55,775
# 568      1,00,08,914     17,00,000
#
# [2013 rows x 6 columns]

# %% [markdown]
# # Questions

# %% [markdown]
# ### 1) Parties contested the election and Total no. of seats of parties in Lok Sabha?

# %%
#table of party contested
total_5
# Out:
# BJP       420
# INC       413
# NOTA      245
# IND       201
# BSP       163
# others    721
# Name: PARTY, dtype: int64

# %%
#table of party won
final_list
# Out:
# BJP      300
# INC       52
# DMK       23
# AITC      22
# YSRCP     22
# other    102
# Name: PARTY, dtype: int64

# %%
#PIE-CHART OF PARTIES CONTESTED....
plt.figure(figsize=(12,6))
plt.title('Parties Contested the Elections ')
plt.pie(total_5,labels=total_5.index,autopct='%1.1f%%',startangle =180);

#PIE -CHART OF PARTIES WON....
plt.figure(figsize=(12,6))
plt.title('Parties Won the Elections')
plt.pie(final_list,labels=final_list.index,autopct='%1.1f%%',startangle =180);

# %% [markdown]
# Observation from Graph 1
#
# We can clearly see that BJP is the aprty which contested at maximum seats with over 19.4% of total seats and INC with second highest number i.e. 19.1% not a major difference 3 rd hihest party is IND which contested at 11.3% of total seats

# %% [markdown]
# Observation from Graph 2
#
# We can clearly see that BJP coming as a majority party which won at 57.6% of total seats in Loksabha . While INC comimg at second with 10% of total sets followed by DMk at 4.4% of total seats.

# %% [markdown]
# #### Q Gender of ratio contested the election and how many of them won?

# %%
gender_df=elec_df.GENDER.value_counts()
gender_df
# Out:
# MALE      1760
# FEMALE     258
# Name: GENDER, dtype: int64

# %%
gender_winner=elec_winner.GENDER.value_counts()
gender_winner
# Out:
# MALE      463
# FEMALE     76
# Name: GENDER, dtype: int64

# %%
#Ratio of contestant ine election
plt.figure(figsize=(12,6))
plt.title('Gender percentage who contest the Election')
plt.pie(gender_df,labels=gender_df.index,autopct='%1.1f%%',startangle =180);
#ratio of the won
plt.figure(figsize=(12,6))
plt.title('WINNER GENDER RATIO')
plt.pie(gender_winner,labels=gender_winner.index,autopct='%1.1f%%',startangle =180);

# %% [markdown]
# Graph 1
# There are 87.2% of total male and 12.8% of female candidate contesting the elections.
#
# Graph 2
# We can observe the percentage of women leader increase to the percentage of contested the election i.e there are 14.1% of total women leader in LS and 85.9% of male candidates wich decreased from 87% of candidate contested the elections

# %% [markdown]
# ### Q. Visualize the graph on contestant category and winners category?

# %%
#Based on category contesting the elction
plt.figure(figsize=(12,6))
plt.title('Category percentage contest the Election')
plt.pie(category_df,labels=category_df.index,autopct='%1.1f%%',startangle =180);

#Based on category won
plt.figure(figsize=(12,6))
plt.title('Category percentage WON the Election')
plt.pie(category_winner,labels=category_winner.index,autopct='%1.1f%%',startangle =180);

# %% [markdown]
# Visualized the graph based on category of the contestant  category

# %% [markdown]
# ###  Q Contestant won by maximum Margin?

# %%
margin_df
# Out:
#                      NAME  PARTY    CONSTITUENCY             STATE  \
# 2248         Rahul Gandhi    INC         WAYANAD            Kerala
# 1068        Kishan Kapoor    BJP          KANGRA  Himachal Pradesh
# 886     UDAY PRATAP SINGH    BJP     HOSHANGABAD    Madhya Pradesh
# 1367   RAM SWAROOP SHARMA    BJP           MANDI  Himachal Pradesh
# 2175     ANANTKUMAR HEGDE    BJP  UTTARA KANNADA         Karnataka
# 1025    Y.S.Avinash Reddy  YSRCP          KADAPA    Andhra Pradesh
# 1113          Jothimani S    INC           KARUR        Tamil Nadu
# 650         RAMESWAR TELI    BJP       DIBRUGARH             Assam
# 840   ANURAG SINGH THAKUR    BJP        HAMIRPUR  Himachal Pradesh
# 1566          C. R. Patil    BJP         NAVSARI           Gujarat
#
#       TOTAL\nVOTES  Win By
# 2248        706367    52.0
# 1068        725218    51.0
# 886         877927    51.0
# 1367        647189    51.0
# 2175        786042    50.0
# 1025        783499    50.0
# 1113        695697    50.0
# 650         659583    50.0
# 840         682692    50.0
# 1566        972739    49.0

# %% [markdown]
# We have extracted top 10 contestant that won with maximum margin.

# %%
x = margin_df['NAME']
y = margin_df['Win By']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='r')
plt.plot(x,y,color='g')
plt.xticks(rotation =60)
plt.title('WIN BY MOST MARGIN',color='r')
plt.xlabel('NAME OF POLITICIAN',color='r')
plt.ylabel('% of vote from Constituency',color='r');

# %% [markdown]
# We  can see from graph rahul gandhi from INC won with maximum margin i.e. 52% which is maximum by any other contestant
# then there was tie b/w 3 contestant which won it with equal margin i.e. is 51%

# %% [markdown]
# ### Q Contestant got least Votes?

# %%
least_df
# Out:
#                         NAME  PARTY  CONSTITUENCY            STATE  \
# 104           GH. MOHD. WANI    IND      ANANTNAG  Jammu & Kashmir
# 103           CH. ZAFFAR ALI    JPC      ANANTNAG  Jammu & Kashmir
# 2007  Sheikh Khalid Jehangir    BJP      SRINAGAR  Jammu & Kashmir
# 287   SYED NAJEEB SHAH NAQVI    IND     BARAMULLA  Jammu & Kashmir
# 1057   RAVINDRA (PINTU) KENE    BSP        KALYAN      Maharashtra
# 1894        N . SHANKAR GOUD    JnP   SECUNDRABAD        Telangana
# 1095            MAMTA PANDEY  RSPSR       KARAKAT            Bihar
# 1701                    NOTA   NOTA          PUNE      Maharashtra
# 1880            ASHOK BAITHA    IND  SASARAM (SC)            Bihar
# 1470  KUMAR NAVNEET HIMANSHU    BSP        MUNGER            Bihar
#
#       TOTAL\nVOTES    Win By
# 104           1369  0.097941
# 103           1646  0.117758
# 2007          4631  0.357697
# 287           4967  0.376934
# 1057          9627  0.489755
# 1894          9683  0.491953
# 1095          8851  0.499702
# 1701         11001  0.529958
# 1880         10029  0.560944
# 1470         10612  0.562069

# %%
x = least_df['NAME']
y = least_df['Win By']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='r')
plt.plot(x,y,color='g')
plt.xticks(rotation =60)
plt.title('Got Least Vote',color='r')
plt.xlabel('NAME OF POLITICIAN',color='r')
plt.ylabel('% of vote from Constituency',color='r');

# %% [markdown]
# contestant who secured least votes in LS election there are contest with less then 0.1% of total votes with least vote of Gh. Mohd Wani from J&K gained only 0.097% of total voting

# %% [markdown]
# ### Q. Contestant with maximum number of criminal case?
# ### Q. LS member with most number of criminal case?

# %%
crime_df
# Out:
#      PARTY                         NAME    CONSTITUENCY          STATE  \
# 1650   BJP                  K SURENDRAN  PATHANAMTHITTA         Kerala
# 903    INC          Adv. DEAN KURIAKOSE          IDUKKI         Kerala
# 0      BJP               SOYAM BAPU RAO        ADILABAD      Telangana
# 1361   INC        ANUMULA REVANTH REDDY      MALKAJGIRI      Telangana
# 2020   INC                George Tirkey      SUNDARGARH         Odisha
# 167    BJP               SOBHASURENDRAN        ATTINGAL         Kerala
# 1303  JAPL  Rajesh Ranjan @ Pappu Yadav       MADHEPURA          Bihar
# 457    BSP                 YOGESH VERMA     BULANDSHAHR  Uttar Pradesh
# 321    BJP                  ARJUN SINGH     BARRACKPORE    West Bengal
# 1233   BJP             Adv.PRAKASH BABU       KOZHIKODE         Kerala
#
#       CRIMINAL\nCASES
# 1650              240
# 903               204
# 0                  52
# 1361               42
# 2020               41
# 167                40
# 1303               31
# 457                28
# 321                24
# 1233               22

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('No. of Criminal Cases')
plt.xlabel('Name of Contestant')
plt.ylabel('No. of Cases')
plt.plot(crime_df['NAME'],crime_df['CRIMINAL\nCASES'])
plt.scatter(crime_df['NAME'],crime_df['CRIMINAL\nCASES'],c='r');

# %% [markdown]
# There are contestat in the election with near 240 criminal cases on them K. sunderan who has about 240 criminal cases on him.
# while prakash babu who is last in top 10 criminal contestant has about 22 Criminal cases on him.

# %%
crime_win
# Out:
#      PARTY                       NAME CONSTITUENCY          STATE  \
# 903    INC        Adv. DEAN KURIAKOSE       IDUKKI         Kerala
# 0      BJP             SOYAM BAPU RAO     ADILABAD      Telangana
# 1361   INC      ANUMULA REVANTH REDDY   MALKAJGIRI      Telangana
# 321    BJP                ARJUN SINGH  BARRACKPORE    West Bengal
# 2259   TRS                  B.B.PATIL    ZAHIRABAD      Telangana
# 882    BJP          LOCKET CHATTERJEE      HOOGHLY    West Bengal
# 409    INC  Komati Reddy Venkat Reddy      BHONGIR      Telangana
# 1415   BJP                Dilip Ghosh    MEDINIPUR    West Bengal
# 785    BSP           ATUL KUMAR SINGH        GHOSI  Uttar Pradesh
# 1074   BJP              SUBRAT PATHAK      KANNAUJ  Uttar Pradesh
#
#       CRIMINAL\nCASES
# 903               204
# 0                  52
# 1361               42
# 321                24
# 2259               18
# 882                14
# 409                14
# 1415               14
# 785                13
# 1074               11

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('No. of Criminal Cases')
plt.xlabel('Name of Contestant')
plt.ylabel('No. of Cases')
plt.plot(crime_win['NAME'],crime_win['CRIMINAL\nCASES'])
plt.scatter(crime_win['NAME'],crime_win['CRIMINAL\nCASES'],c='r');

# %% [markdown]
# Adv. Dean kuriakose top the list of most number of criminal cases as lok sabha member he won the seat from IDDUKI,Kerala with 204 criminal cases.
# While subrat pathak is at least with about 11  cases and a member of lok sabha

# %% [markdown]
# ### Q. Oldest contestant to contest
# ### Q. Oldest person to won?

# %%
age_df
# Out:
#       PARTY                      NAME CONSTITUENCY            STATE   AGE
# 1855     SP  DR. SHAFIQUR REHMAN BARQ      SAMBHAL    Uttar Pradesh  86.0
# 2137  JD(S)           H. D. DEVEGOWDA       TUMKUR        Karnataka  86.0
# 2006    JKN           Farooq Abdullah     SRINAGAR  Jammu & Kashmir  83.0
# 939     SAD     Charanjit Singh Atwal    JALANDHAR           Punjab  82.0
# 797     IND               K. Rangaiah        GODDA        Jharkhand  82.0

# %%
x= age_df['NAME']
y= age_df['AGE']
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('OLDEST CONTESTANT TO RUN THE ELECTION')
plt.scatter(x,y)
plt.plot(x,y);

# %%
win_age
# Out:
#      PARTY                      NAME CONSTITUENCY            STATE   AGE
# 1855    SP  DR. SHAFIQUR REHMAN BARQ      SAMBHAL    Uttar Pradesh  86.0
# 2006   JKN           Farooq Abdullah     SRINAGAR  Jammu & Kashmir  83.0
# 1387  AITC     CHOUDHURY MOHAN JATUA   MATHURAPUR      West Bengal  80.0
# 1348    SP       MULAYAM SINGH YADAV     MAINPURI    Uttar Pradesh  79.0
# 712    INC          Mohammad Sadique     FARIDKOT           Punjab  78.0

# %%
x= win_age['NAME']
y= win_age['AGE']
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('OLDEST CONTESTANT TO won THE ELECTION')
plt.scatter(x,y)
plt.plot(x,y);

# %% [markdown]
# This graph comprise of oldest member of lok sabha dr. sabha bariq from up with age of 86 is oldest member of loksabha

# %% [markdown]
# ### Q City wich pools maximum no. of Votes?

# %%
most_elector
# Out:
#                STATE         CONSTITUENCY  TOTAL ELECTORS
# 1365       Telangana           MALKAJGIRI         3150313
# 238        Karnataka      BANGALORE NORTH         2849250
# 780    Uttar Pradesh            GHAZIABAD         2728978
# 242        Karnataka      BANGALORE RURAL         2497458
# 518        Telangana             CHEVELLA         2443112
# 1596    NCT OF Delhi     NORTH WEST DELHI         2378995
# 2250    NCT OF Delhi           WEST DELHI         2371644
# 2058     Maharashtra                THANE         2370903
# 906   Madhya Pradesh               INDORE         2350580
# 761    Uttar Pradesh  GAUTAM BUDDHA NAGAR         2302960

# %%
x= most_elector['CONSTITUENCY']
y= most_elector['TOTAL ELECTORS']
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('CITIES WITH HIGHEST ELECTORS')
plt.scatter(x,y)
plt.plot(x,y);

# %% [markdown]
# As India is democratic country and it is imporatnt to vote to choose the correct representive so malkajgiri from telangana has maximum election pool in LS election

# %% [markdown]
# ### Q No. of contestant with different Educations level?

# %%
edu_df
# Out:
# Post Graduate            502
# Graduate                 441
# Graduate Professional    336
# 12th Pass                256
# 10th Pass                196
# 8th Pass                  78
# Doctorate                 73
# Others                    50
# Literate                  30
# 5th Pass                  28
# Name: EDUCATION, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title('EDUCATION OF CONTESTANT')
count =0
number= pd.DataFrame(edu_df)
number['num'] = edu_df
for i in number['num']:
    plt.text(count-0.1,i+1,str(i),c='black')
    count+=1
sns.barplot(edu_df.index,edu_df);
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As education is important things that play a amjor ole in a person act and behaviour so we extracted information based on thier education level so we can see that there are 502 candidates who are post graduate in their respective fiELD and there are only 28 who has only studied till 5 class.

# %% [markdown]
# # By Aniket Vyas
